# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
i = np.zeros([5,20,3])

# %%
plt.imshow(i)

# %%
# !wget  https://cdn.esawebb.org/archives/images/screen/weic2216b.jpg
# Out:
# --2023-09-21 14:35:48--  https://cdn.esawebb.org/archives/images/screen/weic2216b.jpg
# Resolving cdn.esawebb.org (cdn.esawebb.org)... 212.102.46.9, 2a02:6ea0:d800::2
# Connecting to cdn.esawebb.org (cdn.esawebb.org)|212.102.46.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1088429 (1.0M) [image/jpeg]
# Saving to: ‘weic2216b.jpg’
#
# weic2216b.jpg       100%[===================>]   1.04M  --.-KB/s    in 0.04s
#
# 2023-09-21 14:35:49 (23.1 MB/s) - ‘weic2216b.jpg’ saved [1088429/1088429]

# %%
import cv2
image1 = cv2.imread('weic2216b.jpg')
print(image1)
# Out:
# [[[ 58  50  37]
#   [ 32  24  11]
#   [ 33  25  12]
#   ...
#   [ 59  54  56]
#   [ 55  49  54]
#   [ 62  56  61]]
#
#  [[ 91  83  70]
#   [ 45  37  24]
#   [ 34  26  13]
#   ...
#   [119 114 116]
#   [ 83  77  82]
#   [ 57  51  56]]
#
#  [[ 47  39  26]
#   [ 41  33  20]
#   [ 43  34  24]
#   ...
#   [187 182 184]
#   [ 75  71  76]
#   [ 63  59  64]]
#
#  ...
#
#  [[  0  14  79]
#   [  0  18  80]
#   [  7  31  91]
#   ...
#   [ 41  19   8]
#   [ 52   8   0]
#   [ 84  29  16]]
#
#  [[  2  21  82]
#   [  0  13  74]
#   [  6  25  86]
#   ...
#   [ 21   2   0]
#   [ 58  16   3]
#   [101  49  36]]
#
#  [[  8  27  84]
#   [  8  27  84]
#   [  0  19  76]
#   ...
#   [105  89  76]
#   [ 59  22   8]
#   [ 87  41  24]]]

# %%
plt.imshow(image1)

# %%
image1.shape
# Out:
# (2217, 1280, 3)

# %%
#length = 2217
#width = 1280
#channels = 3

# %%
image = cv2.cvtColor(image1,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image)

# %%
plt.subplot(1,2,1)
plt.imshow(image1)

plt.subplot(1,2,2)
plt.imshow(image)

# %%
image2 = image.copy()

# %%
plt.imshow(image2)

# %%
#creating a small UFO in the image LOL!

image2[1310:1320,1105:1145,0] = 255
image2[1320:1330,1100:1150,1] = 255
image2[1330:1340,1105:1145,0] = 255
image2[1320:1330,1090:1100,0] = 255
image2[1320:1330,1150:1160,0] = 255
image2[1310:1320,1095:1105,0] = 255
image2[1330:1340,1095:1105,0] = 255
image2[1330:1340,1145:1155,0] = 255
image2[1310:1320,1145:1155,0] = 255
image2[1320:1330,1100:1110,0] = 255
image2[1320:1330,1120:1130,0] = 255
image2[1320:1330,1140:1150,0] = 255

# %%
#a = image [1300:1350,1100:1150,0]  #just to reset if it become a hellbound creature rather than a UFO

# %%
plt.subplot(1,2,1)
plt.imshow(image)

plt.subplot(1,2,2)
plt.imshow(image2)

# %%
UFO = image2[1250:1500,1000:]

# %%
plt.imshow(UFO) #looks more like character from nintendo :-D
#but since it is my first image manipulation so no judging

# %%
#Writing my name
#Letter R
i[:,1:2,0] = 255
i[0:1,1:4,0] = 255
i[:2,3:4,0] = 255
i[2:3,1:4,0] = 255
i[3:4,2:3,0] = 255
i[4:5,3:4,0] = 255

#Letter A

i[:,6:7,1] = 255
i[0:1,6:9,1] = 255
i[:,8:9,1] = 255
i[2:3,6:9,1] = 255

#Letter V
i[4:5,12:13,2] = 255
i[0:4,11:12,2]=255
i[0:4,13:14,2]=255

#Letter I
i[:,17:18,0] = 255
i[0:1,16:19,0] = 255
i[4:5,16:19,0]=255

# %%
plt.imshow(i)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
