# %%
import spacy
import pandas as pd

# %%
my_file = open('/content/sample_data/california_housing_train.csv','r')
file = my_file.read()
my_file.close()
print(file)

# %%
#en_core_web_sm - English_core model_trained on websites_small model
# en - language
# core - type of model
# web - material on which the model is trained
# sm - Size of model (small, mid, large)

# %%
#spacy.cli.download('en_core_web_lg')
nlp = spacy.load('en_core_web_sm')

# %%
sent1 = '''Distributed representations of words in a vector space help learning algorithms to achieve better performance in natural language processing tasks by grouping similar words.
One of the earliest use of word representations dates back to 1986 due to Rumelhart, Hinton, and Williams'''

# %%
doc1 = nlp(sent1)

# %%
for word in doc1:
  print(word)
# Out:
# Distributed
# representations
# of
# words
# in
# a
# vector
# space
# help
# learning
# algorithms
# to
# achieve
# better
# performance
# in
# natural
# language
# processing
# tasks
# by
# grouping
# similar
# words
# .
#
#
# One
# of
# the
# earliest
# use
# of
# word
# representations
# dates
# back
# to
# 1986
# due
# to
# Rumelhart
# ,
# Hinton
# ,
# and
# Williams

# %%
for sent in doc1.sents:
  print(sent,'\n')
# Out:
# Distributed representations of words in a vector space help learning algorithms to achieve better performance in natural language processing tasks by grouping similar words.
#
#
# One of the earliest use of word representations dates back to 1986 due to Rumelhart, Hinton, and Williams

# %%
for ent in doc1.ents:
  print(ent,ent.label_)
# Out:
# One CARDINAL
# 1986 DATE
# Rumelhart, ORG
# Hinton GPE
# Williams PERSON

# %%
for word in doc1:
  print(f'{word}, is digit={word.is_digit}, is punct={word.is_punct}, is_stop = {word.is_stop}','\n')
# Out:
# Distributed, is digit=False, is punct=False, is_stop = False
#
# representations, is digit=False, is punct=False, is_stop = False
#
# of, is digit=False, is punct=False, is_stop = True
#
# words, is digit=False, is punct=False, is_stop = False
#
# in, is digit=False, is punct=False, is_stop = True
#
# a, is digit=False, is punct=False, is_stop = True
#
# vector, is digit=False, is punct=False, is_stop = False
#
# space, is digit=False, is punct=False, is_stop = False
#
# help, is digit=False, is punct=False, is_stop = False
#
# learning, is digit=False, is punct=False, is_stop = False
#
# algorithms, is digit=False, is punct=False, is_stop = False
#
# to, is digit=False, is punct=False, is_stop = True
#
# achieve, is digit=False, is punct=False, is_stop = False
#
# better, is digit=False, is punct=False, is_stop = False
#
# performance, is digit=False, is punct=False, is_stop = False
#
# in, is digit=False, is punct=False, is_stop = True
#
# ...

# %%
doc2 = nlp(
    """
    One of the most difficult problems in finance right now is figuring out the fundamental economic value of cryptocurrencies. And the past week has complicated this further.

    For many cryptocurrency investors, the value of Bitcoin is based on the fact it is artificially scarce. A hard cap on “minting” new coins means there will only ever be 21 million Bitcoin in existence. And unlike national currencies such as the Australian dollar, the rate of release for new Bitcoin is slowing down over time.

    Dogecoin, a cryptocurrency that takes its name and logo from a Shiba Inu meme that was popular several years ago, does not have a cap. Launched in 2013, there are now 100
    """
)

# %%
for ent in doc2.ents:
  print(ent,ent.label_)
# Out:
# One CARDINAL
# the past week DATE
# Bitcoin PERSON
# 21 million CARDINAL
# Australian NORP
# Bitcoin PERSON
# Dogecoin ORG
# Shiba GPE
# several years ago DATE
# 2013 DATE
# 100 CARDINAL

# %%
"""
category of Nouns/entities that can be identified by spacy

PERSON:      People, including fictional.
NORP:        Nationalities or religious or political groups.
FAC:         Buildings, airports, highways, bridges, etc.
ORG:         Companies, agencies, institutions, etc.
GPE:         Countries, cities, states.
LOC:         Non-GPE locations, mountain ranges, bodies of water.
PRODUCT:     Objects, vehicles, foods, etc. (Not services.)
EVENT:       Named hurricanes, battles, wars, sports events, etc.
WORK_OF_ART: Titles of books, songs, etc.
LAW:         Named documents made into laws.
LANGUAGE:    Any named language.
DATE:        Absolute or relative dates or periods.
TIME:        Times smaller than a day.
PERCENT:     Percentage, including ”%“.
MONEY:       Monetary values, including unit.
QUANTITY:    Measurements, as of weight or distance.
ORDINAL:     “first”, “second”, etc.
CARDINAL:    Numerals that do not fall under another type.

"""

# %%
spacy.displacy.render(doc2,style = 'ent',jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"><br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     One
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the most difficult problems in finance right now is figuring out the fundamental economic value of cryptocurrencies. And
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the past week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  has complicated this further.<br><br>    For many cryptocurrency investors, the value of
# ...

# %%
spacy.displacy.render(doc2,style = 'dep',jupyter = True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="076e0b3d90164d60a1645254d30d3cc9-0" class="displacy" width="20875" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">
#     </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">One</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
# ...

# %%
spacy.displacy.render(doc1,style = 'ent',jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Distributed representations of words in a vector space help learning algorithms to achieve better performance in natural language processing tasks by grouping similar words. <br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     One
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the earliest use of word representations dates back to
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1986
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  due to
# ...

# %%
print ("{:<15} | {:<8} | {:<15}".format('Token','Relation','Head'))
print("-"*45)
for word in doc1:
  if word.is_punct == False:
    if word.is_space == False:
      print ("{:<15} | {:<8} | {:<15}".format(str(word),str(word.dep_),str(word.head.head)))
# Out:
# Token           | Relation | Head
# ---------------------------------------------
# Distributed     | amod     | representations
# representations | ROOT     | representations
# of              | prep     | representations
# words           | pobj     | representations
# in              | prep     | representations
# a               | det      | in
# vector          | compound | in
# space           | compound | in
# help            | pobj     | representations
# learning        | acl      | in
# algorithms      | dobj     | help
# to              | aux      | learning
# achieve         | advcl    | help
# better          | amod     | achieve
# performance     | dobj     | learning
# in              | prep     | achieve
# natural         | amod     | tasks
# language        | compound | in
# processing      | compound | in
# tasks           | pobj     | performance
# by              | prep     | learning
# grouping        | pcomp    | achieve
# similar         | amod     | grouping
# ...

# %%
spacy.displacy.render(doc1,style = 'dep',jupyter = True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="5ac0555fe7124a3d9f4a11aee6a5ea88-0" class="displacy" width="7575" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Distributed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">representations</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
# ...

# %%
nlp.Defaults.stop_words
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
# ...

# %%
print('{:<15} | {:<10}'.format('Word','Pos'))
for word in doc2:
  print('{:<15} | {:<10}'.format(str(word),str(word.pos_)))
# Out:
# Word            | Pos
#
#                | SPACE
# One             | NUM
# of              | ADP
# the             | DET
# most            | ADV
# difficult       | ADJ
# problems        | NOUN
# in              | ADP
# finance         | NOUN
# right           | ADV
# now             | ADV
# is              | AUX
# figuring        | VERB
# out             | ADP
# the             | DET
# fundamental     | ADJ
# economic        | ADJ
# value           | NOUN
# of              | ADP
# cryptocurrencies | NOUN
# .               | PUNCT
# And             | CCONJ
# the             | DET
# past            | ADJ
# week            | NOUN
# has             | AUX
# complicated     | VERB
# this            | PRON
# further         | ADV
# .               | PUNCT
#
#
#               | SPACE
# For             | ADP
# many            | ADJ
# cryptocurrency  | NOUN
# investors       | NOUN
# ,               | PUNCT
# the             | DET
# value           | NOUN
# of              | ADP
# ...

# %%
non_stop_punct_words = []
for words in doc1:
  if words.is_punct == False:
    if words.is_stop == False:
      if words.is_space == False:
        non_stop_punct_words.append(words.text)

# %%
non_stop_punct_words
# Out:
# ['Distributed',
#  'representations',
#  'words',
#  'vector',
#  'space',
#  'help',
#  'learning',
#  'algorithms',
#  'achieve',
#  'better',
#  'performance',
#  'natural',
#  'language',
#  'processing',
#  'tasks',
#  'grouping',
#  'similar',
#  'words',
#  'earliest',
#  'use',
#  'word',
#  'representations',
#  'dates',
#  '1986',
#  'Rumelhart',
#  'Hinton',
#  'Williams']

# %%
non_stop_punct_lower_words = [word.lower() for word in non_stop_punct_words]

# %%
non_stop_punct_lower_words
# Out:
# ['distributed',
#  'representations',
#  'words',
#  'vector',
#  'space',
#  'help',
#  'learning',
#  'algorithms',
#  'achieve',
#  'better',
#  'performance',
#  'natural',
#  'language',
#  'processing',
#  'tasks',
#  'grouping',
#  'similar',
#  'words',
#  'earliest',
#  'use',
#  'word',
#  'representations',
#  'dates',
#  '1986',
#  'rumelhart',
#  'hinton',
#  'williams']

# %%
from collections import Counter

# %%
c = Counter(non_stop_punct_lower_words)

# %%
c.most_common(10)
# Out:
# [('representations', 2),
#  ('words', 2),
#  ('distributed', 1),
#  ('vector', 1),
#  ('space', 1),
#  ('help', 1),
#  ('learning', 1),
#  ('algorithms', 1),
#  ('achieve', 1),
#  ('better', 1)]
